# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import itertools
import time
import torch
import pylab as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import imageio.v2 as imageio
from PIL import Image

import memory_old as mem   
from feedforward_old import Feedforward

# %% [markdown]
# ## Helper Functions

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %%
class DiscreteActionWrapper(gym.ActionWrapper):
    def __init__(self, env: gym.Env, bins = 5):
        """A wrapper for converting a 1D continuous actions into discrete ones.
        Args:
            env: The environment to apply the wrapper
            bins: number of discrete actions
        """
        assert isinstance(env.action_space, spaces.Box)
        super().__init__(env)
        self.bins = bins
        self.orig_action_space = env.action_space
        self.action_space = spaces.Discrete(self.bins)

    def action(self, action):
        """ discrete actions from low to high in 'bins'
        Args:
            action: The discrete action
        Returns:
            continuous action
        """
        return self.orig_action_space.low + action/(self.bins-1.0)*(self.orig_action_space.high-self.orig_action_space.low)

# %% [markdown]
# # DQN and RND

# %%
class QFunction(Feedforward):
    def __init__(self, observation_dim, action_dim, hidden_sizes=[100,100], 
                 learning_rate = 0.0002):
        super().__init__(input_size=observation_dim, hidden_sizes=hidden_sizes, 
                         output_size=action_dim)
        self.optimizer=torch.optim.Adam(self.parameters(), 
                                        lr=learning_rate, 
                                        eps=0.000001)
        self.loss = torch.nn.SmoothL1Loss() # MSELoss()
    
    def fit(self, observations, actions, targets):
        self.train() # put model in training mode
        self.optimizer.zero_grad()
        # Forward pass
        acts = torch.from_numpy(actions)
        pred = self.Q_value(torch.from_numpy(observations).float(), acts)
        # Compute Loss
        loss = self.loss(pred, torch.from_numpy(targets).float())
        
        # Backward pass
        loss.backward()
        self.optimizer.step()
        return loss.item()
    
    def Q_value(self, observations, actions):
        return self.forward(observations).gather(1, actions[:,None])        
    
    def maxQ(self, observations):
        return np.max(self.predict(observations), axis=-1, keepdims=True)
        
    def greedyAction(self, observations):
        return np.argmax(self.predict(observations), axis=-1)
        

class RND():
    def __init__(self, input_dim, output_dim, hidden_dim=[100,100],
                 learning_rate = 0.0002):
        self.target = Feedforward(input_size = input_dim, hidden_sizes=hidden_dim, 
                                  output_size = output_dim)
        self.predictor = Feedforward(input_size = input_dim, hidden_sizes=hidden_dim, 
                                  output_size = output_dim)
        self.optimizer=torch.optim.Adam(self.predictor.parameters(), 
                                        lr=learning_rate, 
                                        eps=0.000001)
        self.loss = torch.nn.MSELoss()

    def intrinsic_reward(self, observations):
        output_target = self.target(observations).detach()
        output_prediction = self.predictor(observations)
        reward = self.loss(output_target, output_prediction)
        return reward

    def update_pred(self, reward):
        reward.backward()
        self.optimizer.step()

# %%
class DQNAgent(object):
    """
    Agent implementing Q-learning with NN function approximation.    
    """
    def __init__(self, observation_space, action_space, **userconfig):
        
        if not isinstance(observation_space, spaces.box.Box):
            raise UnsupportedSpace('Observation space {} incompatible ' \
                                   'with {}. (Require: Box)'.format(observation_space, self))
        if not isinstance(action_space, spaces.discrete.Discrete):
            raise UnsupportedSpace('Action space {} incompatible with {}.' \
                                   ' (Reqire Discrete.)'.format(action_space, self))
        
        self._observation_space = observation_space
        self._action_space = action_space
        self._action_n = action_space.n
        self._config = {
            "eps": 1.0,            # Epsilon in epsilon greedy policies                        
            "eps_decay": 0.98,     # Epsilon decay rate
            "eps_min": 0.001,       # Minimum epsilon
            "discount": 0.95,
            "buffer_size": int(1e5),
            "batch_size": 128,
            "learning_rate": 0.0002,
            "update_target_every": 20,
            "use_target_net":True
        }
        self._config.update(userconfig)        
        self._eps = self._config['eps']
        
        self.buffer = mem.Memory(max_size=self._config["buffer_size"])
                
        # Q Network
        self.Q = QFunction(observation_dim=self._observation_space.shape[0], 
                           action_dim=self._action_n,
                           learning_rate = self._config["learning_rate"])
        # Q Network
        self.Q_target = QFunction(observation_dim=self._observation_space.shape[0], 
                                  action_dim=self._action_n,
                                  learning_rate = 0)
        self._update_target_net()
        self.train_iter = 0
            
    def _update_target_net(self):        
        self.Q_target.load_state_dict(self.Q.state_dict())

    def act(self, observation, eps=None):
        if eps is None:
            eps = self._eps
        # epsilon greedy
        if np.random.random() > eps:
            action = self.Q.greedyAction(observation)
        else: 
            action = self._action_space.sample()        
        return action
    
    def store_transition(self, transition):
        self.buffer.add_transition(transition)
            
    def train(self, iter_fit=32):
        losses = []
        self.train_iter+=1
        if self._config["use_target_net"] and self.train_iter % self._config["update_target_every"] == 0:
            self._update_target_net()                
        for i in range(iter_fit):

            # sample from the replay buffer
            data=self.buffer.sample(batch=self._config['batch_size'])
            s = np.stack(data[:,0]) # s_t
            a = np.stack(data[:,1]) # a_t
            rew = np.stack(data[:,2])[:,None] # rew  (batchsize,1)
            s_prime = np.stack(data[:,3]) # s_t+1
            done = np.stack(data[:,4])[:,None] # done signal  (batchsize,1)
            
            if self._config["use_target_net"]:
                v_prime = self.Q_target.maxQ(s_prime)
            else:
                v_prime = self.Q.maxQ(s_prime)
            # target
            gamma=self._config['discount']                                                
            td_target = rew + gamma * (1.0-done) * v_prime
            
            # optimize the lsq objective
            fit_loss = self.Q.fit(s, a, td_target)
            
            losses.append(fit_loss)
                
        return losses

# %%
# dqn and rnd agent
class DQNRNDAgent(object):
    """
    Agent implementing Q-learning with NN function approximation.    
    """
    def __init__(self, observation_space, action_space, **userconfig):
        
        if not isinstance(observation_space, spaces.box.Box):
            raise UnsupportedSpace('Observation space {} incompatible ' \
                                   'with {}. (Require: Box)'.format(observation_space, self))
        if not isinstance(action_space, spaces.discrete.Discrete):
            raise UnsupportedSpace('Action space {} incompatible with {}.' \
                                   ' (Reqire Discrete.)'.format(action_space, self))
        
        self._observation_space = observation_space
        self._action_space = action_space
        self._action_n = action_space.n
        self._config = {
            "eps": 1.0,            # Epsilon in epsilon greedy policies 
            "eps_decay": 0.98,     # Epsilon decay rate
            "eps_min": 0.001,       # Minimum epsilon                       
            "discount": 0.95,
            "buffer_size": int(1e5),
            "batch_size": 128,
            "learning_rate": 0.0002,
            "learning_rate_rnd": 0.002,
            "update_target_every": 20,
            "use_target_net":True
        }
        self._config.update(userconfig)        
        self._eps = self._config['eps']
        
        self.buffer = mem.Memory(max_size=self._config["buffer_size"])

        # RND
        self.rnd = RND(input_dim=self._observation_space.shape[0], 
                       output_dim=self._action_n,
                       learning_rate = self._config["learning_rate_rnd"])
                
        # Q Network
        self.Q = QFunction(observation_dim=self._observation_space.shape[0], 
                           action_dim=self._action_n,
                           learning_rate = self._config["learning_rate"])
        # Q Network
        self.Q_target = QFunction(observation_dim=self._observation_space.shape[0], 
                                  action_dim=self._action_n,
                                  learning_rate = 0)
        self._update_target_net()
        self.train_iter = 0
            
    def _update_target_net(self):        
        self.Q_target.load_state_dict(self.Q.state_dict())

    def act(self, observation, eps=None):
        if eps is None:
            eps = self._eps
        # epsilon greedy
        if np.random.random() > eps:
            action = self.Q.greedyAction(observation)
        else: 
            action = self._action_space.sample()        
        return action
    
    def store_transition(self, transition):
        self.buffer.add_transition(transition)
            
    def train(self, iter_fit=32):
        losses = []
        self.train_iter+=1
        if self._config["use_target_net"] and self.train_iter % self._config["update_target_every"] == 0:
            self._update_target_net()                
        for i in range(iter_fit):

            # sample from the replay buffer
            data=self.buffer.sample(batch=self._config['batch_size'])
            s = np.stack(data[:,0]) # s_t
            a = np.stack(data[:,1]) # a_t
            rew = np.stack(data[:,2])[:,None] # rew  (batchsize,1)
            s_prime = np.stack(data[:,3]) # s_t+1
            done = np.stack(data[:,4])[:,None] # done signal  (batchsize,1)

            rew_i = self.rnd.intrinsic_reward(torch.from_numpy(s))
            self.rnd.update_pred(rew_i)  # update predictor      
            
            if self._config["use_target_net"]:
                v_prime = self.Q_target.maxQ(s_prime)
            else:
                v_prime = self.Q.maxQ(s_prime)
            # target
            gamma=self._config['discount']                                                
            td_target = rew + gamma * (1.0-done) * v_prime
            
            # optimize the lsq objective
            fit_loss = self.Q.fit(s, a, td_target)
            
            losses.append(fit_loss)
                
        return losses

# %% [markdown]
# ## Test in Env

# %%
env_name = 'Pendulum-v1'
# env_name = 'CartPole-v0'

env = gym.make(env_name)
if isinstance(env.action_space, spaces.Box):
    env = DiscreteActionWrapper(env,5)

ac_space = env.action_space
o_space = env.observation_space
print(ac_space)
print(o_space)
print(list(zip(env.observation_space.low, env.observation_space.high)))
# Out:
# Discrete(5)
# Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# [(np.float32(-1.0), np.float32(1.0)), (np.float32(-1.0), np.float32(1.0)), (np.float32(-8.0), np.float32(8.0))]

# %% [markdown]
# ### No RND

# %%
use_target = True
target_update = 20
q_agent = DQNAgent(o_space, ac_space, discount=0.95, eps=1.0, 
                   use_target_net=use_target, update_target_every= target_update)

# %%
ob,_info = env.reset()
q_agent.Q.predict(ob)
# Out:
# array([ 0.22120818,  0.09018848,  0.03821607,  0.19315726, -0.03744116],
#       dtype=float32)

# %% [markdown]
# Running some episodes

# %%
stats = []
losses = []

# %%
max_episodes=1200
max_steps=500 
for i in range(max_episodes):
    # print("Starting a new episode")    
    total_reward = 0
    ob, _info = env.reset()
    for t in range(max_steps):
        done = False        
        a = q_agent.act(ob)
        (ob_new, reward, done, trunc, _info) = env.step(a)
        total_reward+= reward
        q_agent.store_transition((ob, a, reward, ob_new, done))            
        ob=ob_new        
        if done: break    
    losses.extend(q_agent.train(32))
    stats.append([i,total_reward,t+1])

    if q_agent._eps > q_agent._config['eps_min']:
        q_agent._eps *= q_agent._config['eps_decay']    
    
    if ((i-1)%20==0):
        print("{}: Done after {} steps. Reward: {}".format(i, t+1, total_reward))
# Out:
# 1: Done after 500 steps. Reward: -3052.7529846081
# 21: Done after 500 steps. Reward: -3557.7066101639552
# 41: Done after 500 steps. Reward: -3468.312557267972
# 61: Done after 500 steps. Reward: -3248.929412691109
# 81: Done after 500 steps. Reward: -3118.21272266957
# 101: Done after 500 steps. Reward: -2673.4880581926723
# 121: Done after 500 steps. Reward: -3080.160539514001
# 141: Done after 500 steps. Reward: -2750.511342176429
# 161: Done after 500 steps. Reward: -2233.637101034711
# 181: Done after 500 steps. Reward: -3199.9925562618987
# 201: Done after 500 steps. Reward: -274.5614830573388
# 221: Done after 500 steps. Reward: -4.129854726183772
# 241: Done after 500 steps. Reward: -2099.00549075911
# 261: Done after 500 steps. Reward: -2318.250846142251
# 281: Done after 500 steps. Reward: -1307.4813828793788
# 301: Done after 500 steps. Reward: -918.410450990291
# 321: Done after 500 steps. Reward: -131.76278881167738
# 341: Done after 500 steps. Reward: -4.150324343140341
# 361: Done after 500 steps. Reward: -3.9709981521513127
# 381: Done after 500 steps. Reward: -530.7936159747447
# 401: Done after 500 steps. Reward: -527.4002048348747
# 421: Done after 500 steps. Reward: -399.4177364478252
# 441: Done after 500 steps. Reward: -4.066124560745452
# 461: Done after 500 steps. Reward: -133.37105253028253
# 481: Done after 500 steps. Reward: -1599.9902930406063
# 501: Done after 500 steps. Reward: -284.10275894239624
# 521: Done after 500 steps. Reward: -2117.5805004386543
# 541: Done after 500 steps. Reward: -259.9091845702892
# 561: Done after 500 steps. Reward: -123.21526442398951
# 581: Done after 500 steps. Reward: -269.9283694277652
# 601: Done after 500 steps. Reward: -291.64279910553756
# 621: Done after 500 steps. Reward: -261.0279754869326
# 641: Done after 500 steps. Reward: -4.989429588616947
# 661: Done after 500 steps. Reward: -129.57825912866087
# 681: Done after 500 steps. Reward: -130.7844026065656
# 701: Done after 500 steps. Reward: -130.96846957588843
# 721: Done after 500 steps. Reward: -120.89659404173663
# 741: Done after 500 steps. Reward: -129.78046163696757
# 761: Done after 500 steps. Reward: -122.80169499574907
# 781: Done after 500 steps. Reward: -130.88180193058017
# 801: Done after 500 steps. Reward: -129.22440053029695
# 821: Done after 500 steps. Reward: -605.9273070541849
# 841: Done after 500 steps. Reward: -324.063750809897
# 861: Done after 500 steps. Reward: -129.86142451029102
# 881: Done after 500 steps. Reward: -241.1132517028779
# 901: Done after 500 steps. Reward: -129.28512488262578
# 921: Done after 500 steps. Reward: -125.31472701159137
# 941: Done after 500 steps. Reward: -240.44970865110423
# 961: Done after 500 steps. Reward: -119.36505001196947
# 981: Done after 500 steps. Reward: -127.76954843678284
# 1001: Done after 500 steps. Reward: -127.48918276689238
# 1021: Done after 500 steps. Reward: -121.27861616864261
# 1041: Done after 500 steps. Reward: -3.2923551026841014
# 1061: Done after 500 steps. Reward: -124.98971871970085
# 1081: Done after 500 steps. Reward: -120.92828928499613
# 1101: Done after 500 steps. Reward: -127.28648434914034
# 1121: Done after 500 steps. Reward: -126.64111327496252
# 1141: Done after 500 steps. Reward: -1.288204077672225
# 1161: Done after 500 steps. Reward: -126.24058595088493
# 1181: Done after 500 steps. Reward: -296.0636886068312

# %%
stats_np = np.asarray(stats)
losses_np = np.asarray(losses)
fig=plt.figure(figsize=(6,3.8))
plt.plot(stats_np[:,1], label="return")
plt.plot(running_mean(stats_np[:,1],20), label="smoothed-return")
plt.legend()

# %%
#fig.savefig(f"DQN_{env_name}_training_w_target_{use_target}-update-{target_update}.pdf")

# %%
plt.figure()
plt.plot(losses_np)

# %%
q_agent.buffer.size
# Out:
# 100000

# %%
buffer = q_agent.buffer.get_all_transitions()
all_states = np.stack(buffer[:, 0])
angles = np.arctan(all_states[:, 1]/ all_states[:, 0])
all_states = np.column_stack((all_states, angles))
bins = 100

# %%
# Compute 3D histogram
hist, xedges, yedges = np.histogram2d(all_states[:, 2], all_states[:, 3], bins=bins) 

xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')
plt.xlabel('angle')
plt.ylabel('angle velocity')
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

dz_ = np.clip(hist, 0, 20).ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz_, zsort='average')
plt.xlabel('angle')
plt.ylabel('angle velocity')
plt.show()

# %% [markdown]
# ### Using RND

# %%
use_target = True
target_update = 20
q_rnd_agent = DQNRNDAgent(o_space, ac_space, discount=0.95, eps=1.0, learning_rate_rnd= 0.002,
                   use_target_net=use_target, update_target_every= target_update)

# %%
ob,_info = env.reset()
print(q_rnd_agent.Q.predict(ob))
print(ob.dtype)
# Out:
# [-0.15994585  0.04306403 -0.01844331  0.14586808 -0.0805288 ]
# float32

# %%
stats = []
stats_intrinsic = []
losses = []

# %%
# with intrinsic rewards
max_episodes=1200
max_steps=500 
for i in range(max_episodes):
    # print("Starting a new episode")    
    total_reward = 0
    total_intrinsic_reward = 0
    list_rew_i = []
    ob, _info = env.reset()
    for t in range(max_steps):
        done = False        
        a = q_rnd_agent.act(ob)
        (ob_new, reward, done, trunc, _info) = env.step(a)
        total_reward+= reward
        # get intrinsic rewards
        reward_i = q_rnd_agent.rnd.intrinsic_reward(torch.from_numpy(ob)).detach().item() #.clamp(-1.0, 1.0)
        list_rew_i.append(reward_i)
        
        # find combined reward
        if t==0:
            combined_reward = reward + reward_i
            total_intrinsic_reward+= reward_i
        elif t>0:
            # normalise intrinsic rewards by running std
            # random = np.random.rand() * 10 # for control with random intrinsic reward
            reward_i_norm = reward_i/np.std(list_rew_i) # normalised intrinsic reward
            combined_reward = reward + reward_i_norm
            total_intrinsic_reward+= reward_i_norm
        q_rnd_agent.store_transition((ob, a, combined_reward, ob_new, done))            
        ob=ob_new        
        if done: break   
    losses.extend(q_rnd_agent.train(32))
    stats.append([i,total_reward,t+1])
    stats_intrinsic.append([i,total_intrinsic_reward,t+1])
    
    if ((i-1)%20==0):
        print("{}: Done after {} steps. Reward: {}. Intrinsic Reward: {}".format(
            i, t+1, total_reward, total_intrinsic_reward))
        
    if q_rnd_agent._eps > q_rnd_agent._config['eps_min']:
        q_rnd_agent._eps *= q_rnd_agent._config['eps_decay']
# Out:
# 1: Done after 500 steps. Reward: -2757.686626367121. Intrinsic Reward: 1135.8540806296621
# 21: Done after 500 steps. Reward: -3067.9847129290342. Intrinsic Reward: 1921.1757343433424
# 41: Done after 500 steps. Reward: -3703.5771182937997. Intrinsic Reward: 829.6449392183705
# 61: Done after 500 steps. Reward: -3821.9556397005535. Intrinsic Reward: 10666.868708477537
# 81: Done after 500 steps. Reward: -2166.012383291775. Intrinsic Reward: 1161.2383772559854
# 101: Done after 500 steps. Reward: -2660.4229038336284. Intrinsic Reward: 1043.946273968781
# 121: Done after 500 steps. Reward: -2097.3039323693674. Intrinsic Reward: 1540.2512518715373
# 141: Done after 500 steps. Reward: -2146.0817483377077. Intrinsic Reward: 2047.3877193458804
# 161: Done after 500 steps. Reward: -3309.0151982515667. Intrinsic Reward: 2314.285934406188
# 181: Done after 500 steps. Reward: -3675.129202992106. Intrinsic Reward: 1413.3198763779033
# 201: Done after 500 steps. Reward: -2204.9645139028476. Intrinsic Reward: 831.6256997769775
# 221: Done after 500 steps. Reward: -2368.440155470269. Intrinsic Reward: 16409.681043673852
# 241: Done after 500 steps. Reward: -1044.1105145941397. Intrinsic Reward: 1673.142782541632
# 261: Done after 500 steps. Reward: -2058.553312259588. Intrinsic Reward: 3590.913070440688
# 281: Done after 500 steps. Reward: -760.1171491327. Intrinsic Reward: 968.2346699433234
# 301: Done after 500 steps. Reward: -2474.592343157863. Intrinsic Reward: 3107.2784330865975
# 321: Done after 500 steps. Reward: -3759.1178177513398. Intrinsic Reward: 71278.93883913764
# 341: Done after 500 steps. Reward: -136.96715161675462. Intrinsic Reward: 30483.883036920684
# 361: Done after 500 steps. Reward: -2384.082035835485. Intrinsic Reward: 2332.036557680458
# 381: Done after 500 steps. Reward: -1062.5451554871674. Intrinsic Reward: 1113.6269507422599
# 401: Done after 500 steps. Reward: -2756.393745659886. Intrinsic Reward: 4301.965340935322
# 421: Done after 500 steps. Reward: -2907.603988492176. Intrinsic Reward: 5079.595581308218
# 441: Done after 500 steps. Reward: -2000.760820985814. Intrinsic Reward: 2322.8136626769797
# 461: Done after 500 steps. Reward: -2677.0863451571117. Intrinsic Reward: 3168.353847172731
# 481: Done after 500 steps. Reward: -2475.408323811237. Intrinsic Reward: 3366.216207530504
# 501: Done after 500 steps. Reward: -2299.5965545983636. Intrinsic Reward: 3028.2633450938392
# 521: Done after 500 steps. Reward: -3735.207289052146. Intrinsic Reward: 1198.9524378513736
# 541: Done after 500 steps. Reward: -386.90629133233875. Intrinsic Reward: 2572.5840577062636
# 561: Done after 500 steps. Reward: -1925.2086785411786. Intrinsic Reward: 4328.675001067989
# 581: Done after 500 steps. Reward: -1785.1472651320419. Intrinsic Reward: 1787.518949488459
# 601: Done after 500 steps. Reward: -261.5939528943665. Intrinsic Reward: 2078.039187549639
# 621: Done after 500 steps. Reward: -4.748767137791821. Intrinsic Reward: 2582699.9059104184
# 641: Done after 500 steps. Reward: -136.29513430696113. Intrinsic Reward: 1762.2937660208215
# 661: Done after 500 steps. Reward: -3751.765974843646. Intrinsic Reward: 850.4750891389608
# 681: Done after 500 steps. Reward: -250.08018697063676. Intrinsic Reward: 3053.8419569039374
# 701: Done after 500 steps. Reward: -132.849143861353. Intrinsic Reward: 489.18740212925746
# 721: Done after 500 steps. Reward: -131.5243176412162. Intrinsic Reward: 2485.879804934201
# 741: Done after 500 steps. Reward: -2895.9573914786524. Intrinsic Reward: 2904.7977687016105
# 761: Done after 500 steps. Reward: -3096.6659312026645. Intrinsic Reward: 3560.546591227775
# 781: Done after 500 steps. Reward: -2924.795776391968. Intrinsic Reward: 4875.603319634959
# 801: Done after 500 steps. Reward: -2631.4022053100916. Intrinsic Reward: 3401.7758403406588
# 821: Done after 500 steps. Reward: -305.6432927660499. Intrinsic Reward: 2434.504307374994
# 841: Done after 500 steps. Reward: -2306.2559327968493. Intrinsic Reward: 6458.238062536932
# 861: Done after 500 steps. Reward: -16.00568984629395. Intrinsic Reward: 7544.362473833304
# 881: Done after 500 steps. Reward: -246.90915905893826. Intrinsic Reward: 2264.2564442289013
# 901: Done after 500 steps. Reward: -12.113493455178906. Intrinsic Reward: 25064.595758238447
# 921: Done after 500 steps. Reward: -4323.528682716677. Intrinsic Reward: 23263.402336858573
# 941: Done after 500 steps. Reward: -128.20573705777142. Intrinsic Reward: 7133.126529610593
# 961: Done after 500 steps. Reward: -139.27280909552618. Intrinsic Reward: 1825.9999136421204
# 981: Done after 500 steps. Reward: -133.865522228313. Intrinsic Reward: 1929.1298596598024
# 1001: Done after 500 steps. Reward: -131.25546696242282. Intrinsic Reward: 2451.056980308576
# 1021: Done after 500 steps. Reward: -280.0052989174795. Intrinsic Reward: 1986.7427515488396
# 1041: Done after 500 steps. Reward: -132.25403466915964. Intrinsic Reward: 1597.6341171120232
# 1061: Done after 500 steps. Reward: -272.54754736109663. Intrinsic Reward: 2498.2390699778425
# 1081: Done after 500 steps. Reward: -12.810553364397844. Intrinsic Reward: 12279.237529527321
# 1101: Done after 500 steps. Reward: -125.42400915735091. Intrinsic Reward: 2021.5580282571063
# 1121: Done after 500 steps. Reward: -127.43473347084068. Intrinsic Reward: 1684.0041693983414
# 1141: Done after 500 steps. Reward: -240.05891418355705. Intrinsic Reward: 1535.484552138358
# 1161: Done after 500 steps. Reward: -15.646911217288617. Intrinsic Reward: 1895.6126143439171
# 1181: Done after 500 steps. Reward: -366.2509996218858. Intrinsic Reward: 4901.879046660152

# %%
stats_np = np.asarray(stats)
stats_intrinsic_np = np.asarray(stats_intrinsic)
losses_np = np.asarray(losses)
fig=plt.figure(figsize=(6,3.8))
plt.plot(stats_np[:,1], label="return")
plt.plot(running_mean(stats_np[:,1],20), label="smoothed-return")
plt.legend()

# %%
#stats_intrinsic_new = stats_intrinsic_np[np.where(stats_intrinsic_np[:, 1]<5000)[0], :]
fig=plt.figure(figsize=(6,3.8))
clipped = np.clip(stats_intrinsic_np[:,1], 0, 5000)
plt.plot(clipped, label="return")
plt.plot(running_mean(clipped,20), label="smoothed-return")
plt.legend()

# %%
plt.figure()
losses_new = losses_np[np.where(losses_np<100)[0]]
plt.plot(np.clip(losses_np, 0, 10))

# %%
buffer = q_rnd_agent.buffer.get_all_transitions()
all_states = np.stack(buffer[:, 0])
angles = np.arctan(all_states[:, 1]/ all_states[:, 0])
all_states = np.column_stack((all_states, angles))
bins = 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 buffer = q_rnd_agent.buffer.get_all_transitions()
#       2 all_states = np.stack(buffer[:, 0])
#       3 angles = np.arctan(all_states[:, 1]/ all_states[:, 0])
#
# NameError: name 'q_rnd_agent' is not defined

# %%
# Compute 3D histogram
hist, xedges, yedges = np.histogram2d(all_states[:, 2], all_states[:, 3], bins=bins) 

xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')
plt.xlabel('angle')
plt.ylabel('angle velocity')
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

dz_ = np.clip(hist, 0, 20).ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz_, zsort='average')
plt.xlabel('angle')
plt.ylabel('angle velocity')
plt.show()

# %% [markdown]
# ## Evaluate (without exploration)

# %% [markdown]
# ### Without RND

# %%
env_eval = gym.make(env_name, render_mode="human")
if isinstance(env_eval.action_space, spaces.Box):
    env_eval = DiscreteActionWrapper(env_eval,5)
save_gif = False

# %%
# load agent if needed
q_agent = DQNAgent(o_space, ac_space, discount=0.95, eps=1.0,
                   use_target_net=use_target, update_target_every= target_update)
q_agent.Q.load_state_dict(torch.load(f'../saved/Pendulum-v1-baseDQN_solved.pth'))
# Out:
# <All keys matched successfully>

# %%
test_stats = []
frames=[]
episodes=10
env_ = env    # without rendering
#env_ = env_eval # with rendering
save_gif = True

if save_gif:
    env_eval = gym.make(env_name, render_mode="rgb_array")
    if isinstance(env_eval.action_space, spaces.Box):
        env_eval = DiscreteActionWrapper(env_eval,5)
        env_=env_eval


for i in range(episodes):
    total_reward = 0
    ob, _info = env_.reset()
    for t in range(max_steps):
        done = False        
        a = q_agent.act(ob, eps=0.0)
        (ob_new, reward, done, trunc, _info) = env_.step(a)
        total_reward+= reward
        ob=ob_new   
        if save_gif:
            img = env_.render()
            img = Image.fromarray(img)
            frames.append(img.resize((img.width // 2, img.height // 2)))     
        if done: break    
    test_stats.append([i,total_reward,t+1])     
env_.close()

# %%
test_stats_np = np.array(test_stats)
print(np.mean(test_stats_np[:,1]), "+-", np.std(test_stats_np[:,1]))

if save_gif:
    imageio.mimsave("../gifs/Pendulum-v1-baseDQN_solved.gif", frames, duration=0.01)
# Out:
# -147.4195351828806 +- 75.78395705815632

# %%
# save agent:if SOLVED
# for dqn_rnd agent, SOLVED configs:
# gamma = 0.95
# eps = 1.0
# eps_decay = 0.98
# eps_min = 0.001
# alpha = 0.0002
# buffer_size: 1e5,
# batch_size: 128,
# update_target_every: 20
# train episodes = 1200
torch.save(q_agent.Q.state_dict(), 
    f'../saved/Pendulum-v1-baseDQN_solved.pth')

import pickle as pk
save_dict = {
    "train_rewards": stats_np,
    "losses": losses_np,
    "buffer": buffer
}
with open("../saved/Pendulum-v1-baseDQN_solved.pk", "wb") as f:
    pk.dump(save_dict, f)

# %% [markdown]
# ### With RND

# %%
env_eval = gym.make(env_name, render_mode="human")
if isinstance(env_eval.action_space, spaces.Box):
    env_eval = DiscreteActionWrapper(env_eval,5)
save_gif = False

# %%
test_stats = []
frames=[]
episodes=100
env_ = env    # without rendering
#env_ = env_eval # with rendering
#save_gif = True

if save_gif:
    env_eval = gym.make(env_name, render_mode="rgb_array")
    if isinstance(env_eval.action_space, spaces.Box):
        env_eval = DiscreteActionWrapper(env_eval,5)
        env_=env_eval

for i in range(episodes):
    total_reward = 0
    ob, _info = env_.reset()
    for t in range(max_steps):
        done = False        
        a = q_rnd_agent.act(ob, eps=0.0)
        (ob_new, reward, done, trunc, _info) = env_.step(a)
        total_reward+= reward
        ob=ob_new  
        if save_gif:
            img = env_.render()
            img = Image.fromarray(img)
            frames.append(img.resize((img.width // 2, img.height // 2)))        
        if done: break    
    test_stats.append([i,total_reward,t+1])     
env.close()

# %%
test_stats_np = np.array(test_stats)
print(np.mean(test_stats_np[:,1]), "+-", np.std(test_stats_np[:,1]))

if save_gif:
    imageio.mimsave("../gifs/Pendulum-v1-RND_solved.gif", frames, duration=0.01)
# Out:
# -156.8056598363572 +- 87.17900288062283

# %%
# save agent:if SOLVED
# for dqn_rnd agent, SOLVED configs:
# gamma = 0.95
# eps = 0.2
# eps_decay = 1.0
# eps_min = 0.001
# alpha = 0.0002
# alpha_rnd: 0.002,
# buffer_size: 1e5,
# batch_size: 128,
# update_target_every: 20
# train episodes = 1200
torch.save(q_rnd_agent.Q.state_dict(), 
    f'../saved/Pendulum-v1-RND_solved.pth')

import pickle as pk
save_dict = {
    "train_rewards": stats_np,
    "train_rewards_intrinsic": stats_intrinsic_np,
    "losses": losses_np,
    "buffer": buffer
}
with open("../saved/Pendulum-v1-RND_solved.pk", "wb") as f:
    pk.dump(save_dict, f)

# %%
import pickle as pkl
with open("../saved/Pendulum-v1-RND_solved.pk", 'rb') as picklefile:
    test = pkl.load(picklefile)
