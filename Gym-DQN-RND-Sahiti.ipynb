# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import itertools
import time
import torch
import pylab as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

import memory as mem   
from feedforward import Feedforward

# %% [markdown]
# ## Helper Functions

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %%
class DiscreteActionWrapper(gym.ActionWrapper):
    def __init__(self, env: gym.Env, bins = 5):
        """A wrapper for converting a 1D continuous actions into discrete ones.
        Args:
            env: The environment to apply the wrapper
            bins: number of discrete actions
        """
        assert isinstance(env.action_space, spaces.Box)
        super().__init__(env)
        self.bins = bins
        self.orig_action_space = env.action_space
        self.action_space = spaces.Discrete(self.bins)

    def action(self, action):
        """ discrete actions from low to high in 'bins'
        Args:
            action: The discrete action
        Returns:
            continuous action
        """
        return self.orig_action_space.low + action/(self.bins-1.0)*(self.orig_action_space.high-self.orig_action_space.low)

# %% [markdown]
# # DQN and RND

# %%
class QFunction(Feedforward):
    def __init__(self, observation_dim, action_dim, hidden_sizes=[100,100], 
                 learning_rate = 0.0002):
        super().__init__(input_size=observation_dim, hidden_sizes=hidden_sizes, 
                         output_size=action_dim)
        self.optimizer=torch.optim.Adam(self.parameters(), 
                                        lr=learning_rate, 
                                        eps=0.000001)
        self.loss = torch.nn.SmoothL1Loss() # MSELoss()
    
    def fit(self, observations, actions, targets):
        self.train() # put model in training mode
        self.optimizer.zero_grad()
        # Forward pass
        acts = torch.from_numpy(actions)
        pred = self.Q_value(torch.from_numpy(observations).float(), acts)
        # Compute Loss
        loss = self.loss(pred, torch.from_numpy(targets).float())
        
        # Backward pass
        loss.backward()
        self.optimizer.step()
        return loss.item()
    
    def Q_value(self, observations, actions):
        return self.forward(observations).gather(1, actions[:,None])        
    
    def maxQ(self, observations):
        return np.max(self.predict(observations), axis=-1, keepdims=True)
        
    def greedyAction(self, observations):
        return np.argmax(self.predict(observations), axis=-1)
        

class RND():
    def __init__(self, input_dim, output_dim, hidden_dim=[100,100],
                 learning_rate = 0.0002):
        self.target = Feedforward(input_size = input_dim, hidden_sizes=hidden_dim, 
                                  output_size = output_dim)
        self.predictor = Feedforward(input_size = input_dim, hidden_sizes=hidden_dim, 
                                  output_size = output_dim)
        self.optimizer=torch.optim.Adam(self.predictor.parameters(), 
                                        lr=learning_rate, 
                                        eps=0.000001)
        self.loss = torch.nn.MSELoss()

    def intrinsic_reward(self, observations):
        output_target = self.target(observations).detach()
        output_prediction = self.predictor(observations)
        reward = self.loss(output_target, output_prediction)
        return reward

    def update_pred(self, reward):
        reward.backward()
        self.optimizer.step()

# %%
class DQNAgent(object):
    """
    Agent implementing Q-learning with NN function approximation.    
    """
    def __init__(self, observation_space, action_space, **userconfig):
        
        if not isinstance(observation_space, spaces.box.Box):
            raise UnsupportedSpace('Observation space {} incompatible ' \
                                   'with {}. (Require: Box)'.format(observation_space, self))
        if not isinstance(action_space, spaces.discrete.Discrete):
            raise UnsupportedSpace('Action space {} incompatible with {}.' \
                                   ' (Reqire Discrete.)'.format(action_space, self))
        
        self._observation_space = observation_space
        self._action_space = action_space
        self._action_n = action_space.n
        self._config = {
            "eps": 1.0,            # Epsilon in epsilon greedy policies                        
            "eps_decay": 0.98,     # Epsilon decay rate
            "eps_min": 0.001,       # Minimum epsilon
            "discount": 0.95,
            "buffer_size": int(1e5),
            "batch_size": 128,
            "learning_rate": 0.0002,
            "update_target_every": 20,
            "use_target_net":True
        }
        self._config.update(userconfig)        
        self._eps = self._config['eps']
        
        self.buffer = mem.Memory(max_size=self._config["buffer_size"])
                
        # Q Network
        self.Q = QFunction(observation_dim=self._observation_space.shape[0], 
                           action_dim=self._action_n,
                           learning_rate = self._config["learning_rate"])
        # Q Network
        self.Q_target = QFunction(observation_dim=self._observation_space.shape[0], 
                                  action_dim=self._action_n,
                                  learning_rate = 0)
        self._update_target_net()
        self.train_iter = 0
            
    def _update_target_net(self):        
        self.Q_target.load_state_dict(self.Q.state_dict())

    def act(self, observation, eps=None):
        if eps is None:
            eps = self._eps
        # epsilon greedy
        if np.random.random() > eps:
            action = self.Q.greedyAction(observation)
        else: 
            action = self._action_space.sample()        
        return action
    
    def store_transition(self, transition):
        self.buffer.add_transition(transition)
            
    def train(self, iter_fit=32):
        losses = []
        self.train_iter+=1
        if self._config["use_target_net"] and self.train_iter % self._config["update_target_every"] == 0:
            self._update_target_net()                
        for i in range(iter_fit):

            # sample from the replay buffer
            data=self.buffer.sample(batch=self._config['batch_size'])
            s = np.stack(data[:,0]) # s_t
            a = np.stack(data[:,1]) # a_t
            rew = np.stack(data[:,2])[:,None] # rew  (batchsize,1)
            s_prime = np.stack(data[:,3]) # s_t+1
            done = np.stack(data[:,4])[:,None] # done signal  (batchsize,1)
            
            if self._config["use_target_net"]:
                v_prime = self.Q_target.maxQ(s_prime)
            else:
                v_prime = self.Q.maxQ(s_prime)
            # target
            gamma=self._config['discount']                                                
            td_target = rew + gamma * (1.0-done) * v_prime
            
            # optimize the lsq objective
            fit_loss = self.Q.fit(s, a, td_target)
            
            losses.append(fit_loss)
                
        return losses

# %%
# dqn and rnd agent
class DQNRNDAgent(object):
    """
    Agent implementing Q-learning with NN function approximation.    
    """
    def __init__(self, observation_space, action_space, **userconfig):
        
        if not isinstance(observation_space, spaces.box.Box):
            raise UnsupportedSpace('Observation space {} incompatible ' \
                                   'with {}. (Require: Box)'.format(observation_space, self))
        if not isinstance(action_space, spaces.discrete.Discrete):
            raise UnsupportedSpace('Action space {} incompatible with {}.' \
                                   ' (Reqire Discrete.)'.format(action_space, self))
        
        self._observation_space = observation_space
        self._action_space = action_space
        self._action_n = action_space.n
        self._config = {
            "eps": 0.05,            # Epsilon in epsilon greedy policies 
            "eps_decay": 0.98,     # Epsilon decay rate
            "eps_min": 0.001,       # Minimum epsilon                       
            "discount": 0.95,
            "buffer_size": int(1e5),
            "batch_size": 128,
            "learning_rate": 0.0002,
            "learning_rate_rnd": 0.0001,
            "update_target_every": 20,
            "use_target_net":True
        }
        self._config.update(userconfig)        
        self._eps = self._config['eps']
        
        self.buffer = mem.Memory(max_size=self._config["buffer_size"])

        # RND
        self.rnd = RND(input_dim=self._observation_space.shape[0], 
                       output_dim=self._action_n,
                       learning_rate = self._config["learning_rate_rnd"])
                
        # Q Network
        self.Q = QFunction(observation_dim=self._observation_space.shape[0], 
                           action_dim=self._action_n,
                           learning_rate = self._config["learning_rate"])
        # Q Network
        self.Q_target = QFunction(observation_dim=self._observation_space.shape[0], 
                                  action_dim=self._action_n,
                                  learning_rate = 0)
        self._update_target_net()
        self.train_iter = 0
            
    def _update_target_net(self):        
        self.Q_target.load_state_dict(self.Q.state_dict())

    def act(self, observation, eps=None):
        if eps is None:
            eps = self._eps
        # epsilon greedy
        if np.random.random() > eps:
            action = self.Q.greedyAction(observation)
        else: 
            action = self._action_space.sample()        
        return action
    
    def store_transition(self, transition):
        self.buffer.add_transition(transition)
            
    def train(self, iter_fit=32):
        losses = []
        self.train_iter+=1
        if self._config["use_target_net"] and self.train_iter % self._config["update_target_every"] == 0:
            self._update_target_net()                
        for i in range(iter_fit):

            # sample from the replay buffer
            data=self.buffer.sample(batch=self._config['batch_size'])
            s = np.stack(data[:,0]) # s_t
            a = np.stack(data[:,1]) # a_t
            rew = np.stack(data[:,2])[:,None] # rew  (batchsize,1)
            s_prime = np.stack(data[:,3]) # s_t+1
            done = np.stack(data[:,4])[:,None] # done signal  (batchsize,1)

            rew_i = self.rnd.intrinsic_reward(torch.from_numpy(s))
            self.rnd.update_pred(rew_i)  # update predictor      
            
            if self._config["use_target_net"]:
                v_prime = self.Q_target.maxQ(s_prime)
            else:
                v_prime = self.Q.maxQ(s_prime)
            # target
            gamma=self._config['discount']                                                
            td_target = rew + gamma * (1.0-done) * v_prime
            
            # optimize the lsq objective
            fit_loss = self.Q.fit(s, a, td_target)
            
            losses.append(fit_loss)
                
        return losses

# %% [markdown]
# ## Test in Env

# %%
# env_name = 'Pendulum-v1'
env_name = 'CartPole-v0'

env = gym.make(env_name)
if isinstance(env.action_space, spaces.Box):
    env = DiscreteActionWrapper(env,5)

ac_space = env.action_space
o_space = env.observation_space
print(ac_space)
print(o_space)
print(list(zip(env.observation_space.low, env.observation_space.high)))
# Out:
# Discrete(2)
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# [(np.float32(-4.8), np.float32(4.8)), (np.float32(-inf), np.float32(inf)), (np.float32(-0.41887903), np.float32(0.41887903)), (np.float32(-inf), np.float32(inf))]
# /Users/schebolu/work_study/coursework/RL_project/.venv/lib/python3.11/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %% [markdown]
# ### No RND

# %%
use_target = True
target_update = 20
q_agent = DQNAgent(o_space, ac_space, discount=0.95, eps=0.2, 
                   use_target_net=use_target, update_target_every= target_update)

# %%
ob,_info = env.reset()
q_agent.Q.predict(ob)
# Out:
# array([-0.02543077, -0.08920185], dtype=float32)

# %% [markdown]
# Running some episodes

# %%
stats = []
losses = []

# %%
max_episodes=1200
max_steps=500 
for i in range(max_episodes):
    # print("Starting a new episode")    
    total_reward = 0
    ob, _info = env.reset()
    for t in range(max_steps):
        done = False        
        a = q_agent.act(ob)
        (ob_new, reward, done, trunc, _info) = env.step(a)
        total_reward+= reward
        q_agent.store_transition((ob, a, reward, ob_new, done))            
        ob=ob_new        
        if done: break    
    losses.extend(q_agent.train(32))
    stats.append([i,total_reward,t+1])

    if q_agent._eps > q_agent._config['eps_min']:
        q_agent._eps *= q_agent._config['eps_decay']    
    
    if ((i-1)%20==0):
        print("{}: Done after {} steps. Reward: {}".format(i, t+1, total_reward))
# Out:
# 1: Done after 11 steps. Reward: 11.0
# 21: Done after 11 steps. Reward: 11.0
# 41: Done after 11 steps. Reward: 11.0
# 61: Done after 11 steps. Reward: 11.0
# 81: Done after 14 steps. Reward: 14.0
# 101: Done after 14 steps. Reward: 14.0
# 121: Done after 20 steps. Reward: 20.0
# 141: Done after 82 steps. Reward: 82.0
# 161: Done after 105 steps. Reward: 105.0
# 181: Done after 110 steps. Reward: 110.0
# 201: Done after 133 steps. Reward: 133.0
# 221: Done after 133 steps. Reward: 133.0
# 241: Done after 128 steps. Reward: 128.0
# 261: Done after 133 steps. Reward: 133.0
# 281: Done after 125 steps. Reward: 125.0
# 301: Done after 130 steps. Reward: 130.0
# 321: Done after 146 steps. Reward: 146.0
# 341: Done after 136 steps. Reward: 136.0
# 361: Done after 129 steps. Reward: 129.0
# 381: Done after 136 steps. Reward: 136.0
# 401: Done after 136 steps. Reward: 136.0
# 421: Done after 119 steps. Reward: 119.0
# 441: Done after 137 steps. Reward: 137.0
# 461: Done after 141 steps. Reward: 141.0
# 481: Done after 131 steps. Reward: 131.0
# 501: Done after 120 steps. Reward: 120.0
# 521: Done after 127 steps. Reward: 127.0
# 541: Done after 128 steps. Reward: 128.0
# 561: Done after 115 steps. Reward: 115.0
# 581: Done after 114 steps. Reward: 114.0
# 601: Done after 141 steps. Reward: 141.0
# 621: Done after 112 steps. Reward: 112.0
# 641: Done after 138 steps. Reward: 138.0
# 661: Done after 122 steps. Reward: 122.0
# 681: Done after 139 steps. Reward: 139.0
# 701: Done after 135 steps. Reward: 135.0
# 721: Done after 116 steps. Reward: 116.0
# 741: Done after 136 steps. Reward: 136.0
# 761: Done after 150 steps. Reward: 150.0
# 781: Done after 142 steps. Reward: 142.0
# 801: Done after 110 steps. Reward: 110.0
# 821: Done after 215 steps. Reward: 215.0
# 841: Done after 118 steps. Reward: 118.0
# 861: Done after 164 steps. Reward: 164.0
# 881: Done after 185 steps. Reward: 185.0
# 901: Done after 167 steps. Reward: 167.0
# 921: Done after 169 steps. Reward: 169.0
# 941: Done after 152 steps. Reward: 152.0
# 961: Done after 144 steps. Reward: 144.0
# 981: Done after 154 steps. Reward: 154.0
# 1001: Done after 112 steps. Reward: 112.0
# 1021: Done after 123 steps. Reward: 123.0
# 1041: Done after 108 steps. Reward: 108.0
# 1061: Done after 106 steps. Reward: 106.0
# 1081: Done after 105 steps. Reward: 105.0
# 1101: Done after 121 steps. Reward: 121.0
# 1121: Done after 26 steps. Reward: 26.0
# 1141: Done after 113 steps. Reward: 113.0
# 1161: Done after 120 steps. Reward: 120.0
# 1181: Done after 124 steps. Reward: 124.0

# %%
stats_np = np.asarray(stats)
losses_np = np.asarray(losses)
fig=plt.figure(figsize=(6,3.8))
plt.plot(stats_np[:,1], label="return")
plt.plot(running_mean(stats_np[:,1],20), label="smoothed-return")
plt.legend()

# %%
#fig.savefig(f"DQN_{env_name}_training_w_target_{use_target}-update-{target_update}.pdf")

# %%
plt.figure()
plt.plot(losses_np)

# %%
q_agent.buffer.size
# Out:
# 100000

# %%
buffer = q_agent.buffer.get_all_transitions()
all_states = np.stack(buffer[:, 0])
angles = np.arctan(all_states[:, 1]/ all_states[:, 0])
all_states = np.column_stack((all_states, angles))
bins = 100

# %%
# Compute 3D histogram
hist, xedges, yedges = np.histogram2d(all_states[:, 2], all_states[:, 3], bins=bins) 

xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')
plt.xlabel('angle')
plt.ylabel('angle velocity')
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

dz_ = np.clip(hist, 0, 20).ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz_, zsort='average')
plt.xlabel('angle')
plt.ylabel('angle velocity')
plt.show()

# %% [markdown]
# ### Using RND

# %%
use_target = True
target_update = 20
q_rnd_agent = DQNRNDAgent(o_space, ac_space, discount=0.95, eps=0.2, 
                   use_target_net=use_target, update_target_every= target_update)

# %%
stats = []
stats_intrinsic = []
losses = []

# %%
# with intrinsic rewards
max_episodes=1200
max_steps=500 
# total_intrinsic_reward = 0
# list_rew_i = []
for i in range(max_episodes):
    # print("Starting a new episode")    
    total_reward = 0
    total_intrinsic_reward = 0
    list_rew_i = []
    ob, _info = env.reset()
    for t in range(max_steps):
        done = False        
        a = q_rnd_agent.act(ob)
        (ob_new, reward, done, trunc, _info) = env.step(a)
        total_reward+= reward
        # get intrinsic rewards
        reward_i = q_rnd_agent.rnd.intrinsic_reward(torch.from_numpy(ob)).detach().clamp(-1.0, 1.0).item()
        list_rew_i.append(reward_i)
        
        # find combined reward
        if t==0:
            combined_reward = reward + reward_i
            total_intrinsic_reward+= reward_i
        elif t>0:
            # normalise intrinsic rewards by running std
            # random = np.random.rand() * 10 # for control with random intrinsic reward
            reward_i_norm = reward_i/np.std(list_rew_i) # normalised intrinsic reward
            combined_reward = reward + reward_i
            total_intrinsic_reward+= reward_i
        q_rnd_agent.store_transition((ob, a, combined_reward, ob_new, done))            
        ob=ob_new        
        if done: break   
    losses.extend(q_rnd_agent.train(32))
    stats.append([i,total_reward,t+1])
    stats_intrinsic.append([i,total_intrinsic_reward,t+1])
    
    if ((i-1)%20==0):
        print("{}: Done after {} steps. Reward: {}. Intrinsic Reward: {}".format(
            i, t+1, total_reward, total_intrinsic_reward))
        
    if q_rnd_agent._eps > q_rnd_agent._config['eps_min']:
        q_rnd_agent._eps *= q_rnd_agent._config['eps_decay']
# Out:
# 1: Done after 11 steps. Reward: 11.0. Intrinsic Reward: 0.6655402816832066
# 21: Done after 10 steps. Reward: 10.0. Intrinsic Reward: 2.005345357581973
# 41: Done after 12 steps. Reward: 12.0. Intrinsic Reward: 1.4696304947137833
# 61: Done after 18 steps. Reward: 18.0. Intrinsic Reward: 0.440572620020248
# 81: Done after 27 steps. Reward: 27.0. Intrinsic Reward: 4.686043901136145
# 101: Done after 24 steps. Reward: 24.0. Intrinsic Reward: 10.39783806912601
# 121: Done after 56 steps. Reward: 56.0. Intrinsic Reward: 23.649488940835
# 141: Done after 200 steps. Reward: 200.0. Intrinsic Reward: 21.588726731017232
# 161: Done after 186 steps. Reward: 186.0. Intrinsic Reward: 38.20976446894929
# 181: Done after 160 steps. Reward: 160.0. Intrinsic Reward: 37.8217535961885
# 201: Done after 135 steps. Reward: 135.0. Intrinsic Reward: 46.94978954270482
# 221: Done after 137 steps. Reward: 137.0. Intrinsic Reward: 60.39181863050908
# /var/folders/r5/35ml8bds4xgg92vk489jvb0r0007ds/T/ipykernel_28727/4142771099.py:28: RuntimeWarning: divide by zero encountered in scalar divide
#   reward_i_norm = reward_i/np.std(list_rew_i) # normalised intrinsic reward
# 241: Done after 134 steps. Reward: 134.0. Intrinsic Reward: 44.709676798433065
# 261: Done after 140 steps. Reward: 140.0. Intrinsic Reward: 77.25730513036251
# 281: Done after 143 steps. Reward: 143.0. Intrinsic Reward: 115.7367214858532
# 301: Done after 131 steps. Reward: 131.0. Intrinsic Reward: 33.08009099960327
# 321: Done after 140 steps. Reward: 140.0. Intrinsic Reward: 16.12035065703094
# 341: Done after 137 steps. Reward: 137.0. Intrinsic Reward: 128.26651215553284
# 361: Done after 133 steps. Reward: 133.0. Intrinsic Reward: 88.05565075948834
# 381: Done after 150 steps. Reward: 150.0. Intrinsic Reward: 94.27807496953756
# 401: Done after 143 steps. Reward: 143.0. Intrinsic Reward: 75.05263639241457
# 421: Done after 155 steps. Reward: 155.0. Intrinsic Reward: 63.91508294455707
# 441: Done after 142 steps. Reward: 142.0. Intrinsic Reward: 49.06058655353263
# 461: Done after 136 steps. Reward: 136.0. Intrinsic Reward: 32.22567803831771
# 481: Done after 138 steps. Reward: 138.0. Intrinsic Reward: 64.9669012556551
# 501: Done after 128 steps. Reward: 128.0. Intrinsic Reward: 73.46123406750849
# 521: Done after 126 steps. Reward: 126.0. Intrinsic Reward: 72.5644229913596
# 541: Done after 131 steps. Reward: 131.0. Intrinsic Reward: 129.9433540403843
# 561: Done after 131 steps. Reward: 131.0. Intrinsic Reward: 116.52554661035538
# 581: Done after 148 steps. Reward: 148.0. Intrinsic Reward: 145.99446856975555
# 601: Done after 143 steps. Reward: 143.0. Intrinsic Reward: 143.0
# 621: Done after 145 steps. Reward: 145.0. Intrinsic Reward: 141.81487888097763
# 641: Done after 161 steps. Reward: 161.0. Intrinsic Reward: 122.33564507961273
# 661: Done after 150 steps. Reward: 150.0. Intrinsic Reward: 150.0
# 681: Done after 149 steps. Reward: 149.0. Intrinsic Reward: 147.89380186796188
# 701: Done after 151 steps. Reward: 151.0. Intrinsic Reward: 133.0150881409645
# 721: Done after 155 steps. Reward: 155.0. Intrinsic Reward: 93.12296190671623
# 741: Done after 156 steps. Reward: 156.0. Intrinsic Reward: 124.63328532129526
# 761: Done after 157 steps. Reward: 157.0. Intrinsic Reward: 140.94941568374634
# 781: Done after 170 steps. Reward: 170.0. Intrinsic Reward: 153.6246199309826
# 801: Done after 157 steps. Reward: 157.0. Intrinsic Reward: 156.10053849220276
# 821: Done after 155 steps. Reward: 155.0. Intrinsic Reward: 148.21370878443122
# 841: Done after 167 steps. Reward: 167.0. Intrinsic Reward: 165.48471729457378
# 861: Done after 173 steps. Reward: 173.0. Intrinsic Reward: 172.95442616939545
# 881: Done after 166 steps. Reward: 166.0. Intrinsic Reward: 166.0
# 901: Done after 157 steps. Reward: 157.0. Intrinsic Reward: 157.0
# 921: Done after 167 steps. Reward: 167.0. Intrinsic Reward: 167.0
# 941: Done after 163 steps. Reward: 163.0. Intrinsic Reward: 163.0
# 961: Done after 176 steps. Reward: 176.0. Intrinsic Reward: 134.0558425616473
# 981: Done after 180 steps. Reward: 180.0. Intrinsic Reward: 147.85564678534865
# 1001: Done after 167 steps. Reward: 167.0. Intrinsic Reward: 162.91798348724842
# 1021: Done after 165 steps. Reward: 165.0. Intrinsic Reward: 145.66326451301575
# 1041: Done after 165 steps. Reward: 165.0. Intrinsic Reward: 165.0
# 1061: Done after 166 steps. Reward: 166.0. Intrinsic Reward: 159.97509530186653
# 1081: Done after 168 steps. Reward: 168.0. Intrinsic Reward: 129.35153452679515
# 1101: Done after 162 steps. Reward: 162.0. Intrinsic Reward: 158.5373176932335
# 1121: Done after 169 steps. Reward: 169.0. Intrinsic Reward: 165.6374232172966
# 1141: Done after 156 steps. Reward: 156.0. Intrinsic Reward: 155.28542092442513
# 1161: Done after 162 steps. Reward: 162.0. Intrinsic Reward: 142.86197763681412
# 1181: Done after 160 steps. Reward: 160.0. Intrinsic Reward: 132.43291671574116

# %%
stats_np = np.asarray(stats)
stats_intrinsic_np = np.asarray(stats_intrinsic)
losses_np = np.asarray(losses)
fig=plt.figure(figsize=(6,3.8))
plt.plot(stats_np[:,1], label="return")
plt.plot(running_mean(stats_np[:,1],20), label="smoothed-return")
plt.legend()

# %%
#stats_intrinsic_new = stats_intrinsic_np[np.where(stats_intrinsic_np[:, 1]<5000)[0], :]
fig=plt.figure(figsize=(6,3.8))
clipped = np.clip(stats_intrinsic_np[:,1], 0, 5000)
plt.plot(clipped, label="return")
plt.plot(running_mean(clipped,20), label="smoothed-return")
plt.legend()

# %%
plt.figure()
losses_new = losses_np[np.where(losses_np<100)[0]]
plt.plot(np.clip(losses_np, 0, 10))

# %%
buffer = q_rnd_agent.buffer.get_all_transitions()
all_states = np.stack(buffer[:, 0])
angles = np.arctan(all_states[:, 1]/ all_states[:, 0])
all_states = np.column_stack((all_states, angles))
bins = 100

# %%
# Compute 3D histogram
hist, xedges, yedges = np.histogram2d(all_states[:, 2], all_states[:, 3], bins=bins) 

xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')
plt.xlabel('angle')
plt.ylabel('angle velocity')
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

dz_ = np.clip(hist, 0, 20).ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz_, zsort='average')
plt.xlabel('angle')
plt.ylabel('angle velocity')
plt.show()

# %% [markdown]
# ## Evaluate (without exploration)

# %% [markdown]
# ### Without RND

# %%
env_eval = gym.make(env_name, render_mode="human")
if isinstance(env.action_space, spaces.Box):
    env_eval = DiscreteActionWrapper(env_eval,5)
# Out:
# /Users/schebolu/work_study/coursework/RL_project/.venv/lib/python3.11/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
test_stats = []
episodes=50
env_ = env    # without rendering
#env_ = env_eval # with rendering

for i in range(episodes):
    total_reward = 0
    ob, _info = env_.reset()
    for t in range(max_steps):
        done = False        
        a = q_agent.act(ob, eps=0.0)
        (ob_new, reward, done, trunc, _info) = env_.step(a)
        total_reward+= reward
        ob=ob_new        
        if done: break    
    test_stats.append([i,total_reward,t+1])     
env.close()

# %%
test_stats_np = np.array(test_stats)
print(np.mean(test_stats_np[:,1]), "+-", np.std(test_stats_np[:,1]))
# Out:
# 118.62 +- 5.688198308779327

# %% [markdown]
# ### With RND

# %%
env_eval = gym.make(env_name, render_mode="human")
if isinstance(env_eval.action_space, spaces.Box):
    env_eval = DiscreteActionWrapper(env_eval,5)

# %%
test_stats = []
episodes=50
env_ = env    # without rendering
#env_ = env_eval # with rendering

for i in range(episodes):
    total_reward = 0
    ob, _info = env_.reset()
    for t in range(max_steps):
        done = False        
        a = q_rnd_agent.act(ob, eps=0.0)
        (ob_new, reward, done, trunc, _info) = env_.step(a)
        total_reward+= reward
        ob=ob_new        
        if done: break    
    test_stats.append([i,total_reward,t+1])     
env.close()

# %%
test_stats_np = np.array(test_stats)
print(np.mean(test_stats_np[:,1]), "+-", np.std(test_stats_np[:,1]))
# Out:
# 167.0 +- 4.8
